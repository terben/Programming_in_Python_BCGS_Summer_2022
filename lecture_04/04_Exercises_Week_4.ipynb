# %% [markdown]
# # Exercises for week 4

# %% [markdown]
# ## physics718: Programming in Physics and Astronomy with C++ or Python (SS 2022)
# Nina Stiesdal & Thomas Erben

# %% [markdown]
# There are only tasks for the exercise class on this sheet. Instead of homework, you got a project to work on this week.
#
#
# **Topics of this exercise:**
#  * first contact with Python-functions
#  * fancy indexing and masking with 1d `numpy`-arrays

# %% [markdown]
# # 1. Lecture Review (0 points)

# %% [markdown]
# If you did the lecture review questions [03_Lecture_Review.ipynb](03_Lecture_Review.ipynb) (strongly recommended!):
# Please discuss with your tutor and your group any issues/problems you had with them.

# %% [markdown]
# # 2. Choose your project (0 points)
# For the first project, we give you the choice of two different tasks to work on. One is on investements in the stock market, a subject that I dealt with more intensively in the past years) and the other on off-shore wind turbine farms (Ninas father is working on that subject).
#
# Please read through both project notebooks and decide which project to work on.
#
# Please feel free to discuss with your peers and to ask questions to your tutor, Nina or myself any time!

# %% [markdown]
# # 3. Video on typical Python mistakes (0 points)

# %% [markdown]
# I made a video on four typical problems that beginners often run into when they start to program in Python. The video is not mandatory course material but I strongly advise you to watch it. Please find it [here](https://youtu.be/weVMhqm3QEg).

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('weVMhqm3QEg')
